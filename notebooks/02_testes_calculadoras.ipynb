# %% [markdown]
# # 🧮 Testes de Calculadoras Financeiras
#
# Demonstração das calculadoras financeiras disponíveis.

# %%
import sys
sys.path.append('..')

from src.calculators import FinancialCalculators
import pandas as pd

# %% [markdown]
# ## 1. Financiamento SAC

# %%
calc = FinancialCalculators()

resultado_sac = calc.calcular_financiamento_sac(
    valor=300000,
    entrada=50000,
    prazo=180,
    taxa=9.5
)

print(f"Valor Financiado: R$ {resultado_sac.valor_financiado:,.2f}")
print(f"Primeira Parcela: R$ {resultado_sac.parcelas[0]:,.2f}")
print(f"Última Parcela: R$ {resultado_sac.parcelas[-1]:,.2f}")
print(f"Total de Juros: R$ {resultado_sac.total_juros:,.2f}")

# %% [markdown]
# ## 2. Financiamento Price

# %%
resultado_price = calc.calcular_financiamento_price(
    valor=300000,
    entrada=50000,
    prazo=180,
    taxa=9.5
)

print(f"Parcela Fixa: R$ {resultado_price.parcelas[0]:,.2f}")
print(f"Total de Juros: R$ {resultado_price.total_juros:,.2f}")

# %% [markdown]
# ## 3. Investimento

# %%
investimento = calc.calcular_investimento(
    valor_inicial=10000,
    aporte_mensal=500,
    taxa=12.0,
    prazo=60
)

print(f"Montante Final: R$ {investimento.montante_final:,.2f}")
print(f"Total Investido: R$ {investimento.total_investido:,.2f}")
print(f"Rendimento: R$ {investimento.total_rendimento:,.2f}")
